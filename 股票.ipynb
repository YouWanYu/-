# %%
import yfinance as yf
import pandas as pd

# %%
start_date='1990-01-01'
end_date='2024-03-31'

# %%
ticker='AMZN'
data=yf.download(ticker,start_date,end_date)
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-22  177.750000  179.259995  176.750000  178.869995  178.869995
# 2024-03-25  178.009995  180.990005  177.240005  179.710007  179.710007
# 2024-03-26  180.149994  180.449997  177.949997  178.300003  178.300003
# 2024-03-27  179.880005  180.000000  177.309998  179.830002  179.830002
# 2024-03-28  180.169998  181.699997  179.259995  180.380005  180.380005
#
#               Volume
# Date
# 2024-03-22  27964100
# 2024-03-25  29815500
# 2024-03-26  29659000
# 2024-03-27  33272600
# 2024-03-28  38051600

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['Adj Close'].plot(figsize=(10,7))
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16) 
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import yfinance as yf
import pandas as pd

# %%
tickers_list=['AAPL','IBM',"2330.tw"]

# %%
data=pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
    data[ticker]=yf.download(ticker,period='10y',interval='1d')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  AAPL         IBM    2330.tw
# Date
# 2014-04-28  18.688705  120.915726        NaN
# 2014-04-29  18.633333  122.149048  89.196259
# 2014-04-30  18.562870  123.000511  87.715836
# 2014-05-01  18.606596  121.159904        NaN
# 2014-05-02  18.641201  119.851395  87.345711

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price", fontsize=16) 
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()
